# %%
from IPython.display import Image
# !pyreverse -o png -p literacy .
# Out:
# parsing ./__init__.py...
# parsing /Users/tfast/lit/__init__.py...
# parsing /Users/tfast/lit/setup.py...
# parsing /Users/tfast/lit/literacy/__init__.py...
# parsing /Users/tfast/lit/literacy/blocks.py...
# parsing /Users/tfast/lit/literacy/environment.py...
# parsing /Users/tfast/lit/literacy/macro.py...
# parsing /Users/tfast/lit/literacy/magic.py...

# %%
IPython.display.Image('packages_literacy.png')

# %%
IPython.display.Image('classes_literacy.png')

# %%
# !pycco ../literacy/*.py -p
# Out:
# pycco: ../literacy/__init__.py -> docs/../literacy/__init__.html
# pycco: ../literacy/blocks.py -> docs/../literacy/blocks.html
# pycco: ../literacy/environment.py -> docs/../literacy/environment.html
# pycco: ../literacy/macro.py -> docs/../literacy/macro.html
# pycco: ../literacy/magic.py -> docs/../literacy/magic.html

# %% [raw]
# import bokeh.plotting
# bokeh.plotting.output_notebook()
#
# import networkx as nx
# G = nx.nx_pydot.read_dot('classes_literacy.dot')
#
# p=bokeh.plotting.figure(webgl=True)
# p.yaxis.visible = p.xaxis.visible = False
# pos = nx.nx_pydot.pydot_layout(G)
# p.text(text=[G.node[p]['label'] for p in pos.keys()],x=[v[0] for v in pos.values()], y=[v[1] for v in pos.values()])
# for source, sink in G.edges_iter():
#     p.line(x=[pos[source][0],pos[sink][0]],y=[pos[source][1],pos[sink][1]])
# bokeh.plotting.show(p)
